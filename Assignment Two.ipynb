# %%
#import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib  inline

# %%
#read csv file
employee_attrition=pd.read_csv("./WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
employee_attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
employee_attrition.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
employee_attrition.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#show the coulmns
employee_attrition.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#breakdown of distance from home by job role and attrition
Breakdown=employee_attrition[["Attrition","DistanceFromHome","JobRole"]]

# %%
Breakdown
# Out:
#      Attrition  DistanceFromHome                    JobRole
# 0          Yes                 1            Sales Executive
# 1           No                 8         Research Scientist
# 2          Yes                 2      Laboratory Technician
# 3           No                 3         Research Scientist
# 4           No                 2      Laboratory Technician
# ...        ...               ...                        ...
# 1465        No                23      Laboratory Technician
# 1466        No                 6  Healthcare Representative
# 1467        No                 4     Manufacturing Director
# 1468        No                 2            Sales Executive
# 1469        No                 8      Laboratory Technician
#
# [1470 rows x 3 columns]

# %%
#attrition=yes
Breakdown1=Breakdown[["Attrition","DistanceFromHome","JobRole"]][Breakdown["Attrition"]=='Yes']

# %%
Breakdown1=Breakdown1.rename(columns={"Attrition":'Attrition(Yes)'})

# %%
Breakdown1
# Out:
#      Attrition(Yes)  DistanceFromHome                JobRole
# 0               Yes                 1        Sales Executive
# 2               Yes                 2  Laboratory Technician
# 14              Yes                24  Laboratory Technician
# 21              Yes                 9   Sales Representative
# 24              Yes                 6     Research Scientist
# ...             ...               ...                    ...
# 1438            Yes                 9   Sales Representative
# 1442            Yes                 1     Research Scientist
# 1444            Yes                 7  Laboratory Technician
# 1452            Yes                 1        Sales Executive
# 1461            Yes                28        Sales Executive
#
# [237 rows x 3 columns]

# %%
#attrition=no
Breakdown2=Breakdown[["Attrition","DistanceFromHome","JobRole"]][Breakdown["Attrition"]=='No']

# %%
Breakdown2=Breakdown2.rename(columns={"Attrition":'Attrition(No)'})

# %%
Breakdown2
# Out:
#      Attrition(No)  DistanceFromHome                    JobRole
# 1               No                 8         Research Scientist
# 3               No                 3         Research Scientist
# 4               No                 2      Laboratory Technician
# 5               No                 2      Laboratory Technician
# 6               No                 3      Laboratory Technician
# ...            ...               ...                        ...
# 1465            No                23      Laboratory Technician
# 1466            No                 6  Healthcare Representative
# 1467            No                 4     Manufacturing Director
# 1468            No                 2            Sales Executive
# 1469            No                 8      Laboratory Technician
#
# [1233 rows x 3 columns]

# %%
Breakdown1.groupby(["DistanceFromHome","JobRole"]).count()
# Out:
#                                             Attrition(Yes)
# DistanceFromHome JobRole
# 1                Human Resources                         1
#                  Laboratory Technician                   4
#                  Manufacturing Director                  1
#                  Research Scientist                      7
#                  Sales Executive                         6
# ...                                                    ...
# 29               Healthcare Representative               1
#                  Laboratory Technician                   1
#                  Manager                                 1
#                  Research Scientist                      1
#                  Sales Executive                         1
#
# [112 rows x 1 columns]

# %%
Breakdown2.groupby(["DistanceFromHome","JobRole"]).count()
# Out:
#                                             Attrition(No)
# DistanceFromHome JobRole
# 1                Healthcare Representative             23
#                  Human Resources                        8
#                  Laboratory Technician                 27
#                  Manager                               13
#                  Manufacturing Director                23
# ...                                                   ...
# 29               Manager                                3
#                  Manufacturing Director                 4
#                  Research Scientist                     3
#                  Sales Executive                        4
#                  Sales Representative                   1
#
# [217 rows x 1 columns]

# %%
#average monthly income by education and attrition
df=employee_attrition[["MonthlyIncome","Education","Attrition"]]

# %%
df
# Out:
#       MonthlyIncome  Education Attrition
# 0              5993          2       Yes
# 1              5130          1        No
# 2              2090          2       Yes
# 3              2909          4        No
# 4              3468          1        No
# ...             ...        ...       ...
# 1465           2571          2        No
# 1466           9991          1        No
# 1467           6142          3        No
# 1468           5390          3        No
# 1469           4404          3        No
#
# [1470 rows x 3 columns]

# %%
df1=df[["MonthlyIncome","Education","Attrition"]][df["Attrition"]=='Yes']

# %%
df1=df1.rename(columns={"Attrition":'Attrition(Yes)'})

# %%
df1
# Out:
#       MonthlyIncome  Education Attrition(Yes)
# 0              5993          2            Yes
# 2              2090          2            Yes
# 14             2028          3            Yes
# 21             3407          4            Yes
# 24             2960          1            Yes
# ...             ...        ...            ...
# 1438           1790          3            Yes
# 1442           4787          4            Yes
# 1444           2339          2            Yes
# 1452           6728          4            Yes
# 1461          10854          3            Yes
#
# [237 rows x 3 columns]

# %%
df1.groupby("Education")["MonthlyIncome"].mean()
# Out:
# Education
# 1    4360.161290
# 2    4282.545455
# 3    4770.242424
# 4    5335.155172
# 5    5850.200000
# Name: MonthlyIncome, dtype: float64

# %%
df2=df[["MonthlyIncome","Education","Attrition"]][df["Attrition"]=='No']

# %%
df2=df2.rename(columns={"Attrition":'Attrition(No)'})

# %%
df2
# Out:
#       MonthlyIncome  Education Attrition(No)
# 1              5130          1            No
# 3              2909          4            No
# 4              3468          1            No
# 5              3068          2            No
# 6              2670          3            No
# ...             ...        ...           ...
# 1465           2571          2            No
# 1466           9991          1            No
# 1467           6142          3            No
# 1468           5390          3            No
# 1469           4404          3            No
#
# [1233 rows x 3 columns]

# %%
df2.groupby("Education")["MonthlyIncome"].mean()
# Out:
# Education
# 1    5926.129496
# 2    6586.058824
# 3    6882.919662
# 4    7087.814706
# 5    8559.906977
# Name: MonthlyIncome, dtype: float64
